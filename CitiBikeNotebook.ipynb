# %%
import pandas as pd
import numpy as np
import statistics

# %%
df1 = pd.read_csv('201907-citibike.csv')
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
df1.rename(columns = {'Trip Duration': 'trip duration', 'Start Time': 'start time',
                      'Stop Time': 'stoptime', 'Gender': 'gender', 'User Type': 'user type',
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', "Start Station Latitude": 'start station latitude', 
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id',
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude', 
                      'End Station Longitude': 'end station longitude'}, inplace = True)
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
df2 = pd.read_csv('201906-citibike.csv')
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
df2.rename(columns = {'Trip Duration': 'trip duration', 'Start Time': 'start time',
                      'Stop Time': 'stoptime', 'Gender': 'gender', 'User Type': 'user type',
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', "Start Station Latitude": 'start station latitude', 
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id',
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude', 
                      'End Station Longitude': 'end station longitude'}, inplace = True)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
df3 = pd.read_csv('201905-citibike.csv')
df3.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 36130           792  2019-05-31 23:51:00.1170  2019-06-01 00:04:12.4530
# 36131           779  2019-05-31 23:51:22.7840  2019-06-01 00:04:22.3990
# 36132           347  2019-05-31 23:55:38.3850  2019-06-01 00:01:26.2030
# 36133           552  2019-05-31 23:56:11.9740  2019-06-01 00:05:24.8810
# 36134           520  2019-05-31 23:56:25.0240  2019-06-01 00:05:05.4860
#
#        start station id  start station name  start station latitude  \
# 36130              3186       Grove St PATH               40.719586
# 36131              3186       Grove St PATH               40.719586
# 36132              3186       Grove St PATH               40.719586
# 36133              3192  Liberty Light Rail               40.711242
# 36134              3192  Liberty Light Rail               40.711242
#
#        start station longitude  end station id         end station name  \
# ...

# %%
df3.rename(columns = {'Trip Duration': 'trip duration', 'Start Time': 'start time',
                      'Stop Time': 'stoptime', 'Gender': 'gender', 'User Type': 'user type',
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', "Start Station Latitude": 'start station latitude', 
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id',
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude', 
                      'End Station Longitude': 'end station longitude'}, inplace = True)
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
citibike_2017 = pd.concat ([df1, df2, df3])
citibike_2017
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# 5               779  2019-07-01 00:04:34.1330  2019-07-01 00:17:34.0800
# 6               123  2019-07-01 00:05:23.5820  2019-07-01 00:07:27.5070
# 7               381  2019-07-01 00:17:31.7600  2019-07-01 00:23:53.0680
# 8               665  2019-07-01 00:31:08.6430  2019-07-01 00:42:14.2910
# 9               509  2019-07-01 01:40:25.3990  2019-07-01 01:48:54.8780
# 10             1336  2019-07-01 01:45:16.3750  2019-07-01 02:07:32.6490
# 11              281  2019-07-01 01:59:40.3030  2019-07-01 02:04:21.6510
# ...

# %%
df4 = citibike_2017
df4.tripduration.mean()
# Out:
# 869.1480332911467

# %%
df4.sort_values(['gender'])
# Out:
#        tripduration                 starttime                  stoptime  \
# 8949           1233  2019-07-07 18:51:46.4900  2019-07-07 19:12:20.4810
# 20868          3800  2019-06-16 21:16:25.3610  2019-06-16 22:19:45.6770
# 24378           235  2019-05-21 17:55:17.5610  2019-05-21 17:59:13.0950
# 2878            716  2019-06-03 10:24:27.0180  2019-06-03 10:36:23.0430
# 20871          1075  2019-06-16 21:20:27.4390  2019-06-16 21:38:22.9420
# 33740           337  2019-06-26 23:05:20.9170  2019-06-26 23:10:58.4430
# 20884          1582  2019-06-16 21:49:28.7210  2019-06-16 22:15:51.2390
# 33737         16840  2019-06-26 23:01:51.0440  2019-06-27 03:42:31.2890
# 33736          3901  2019-06-26 23:01:45.0480  2019-06-27 00:06:46.8660
# 33735         58411  2019-06-26 23:01:44.9030  2019-06-27 15:15:16.2330
# 20897           694  2019-06-16 22:39:39.6440  2019-06-16 22:51:14.0030
# 35669           574  2019-07-26 15:13:51.1930  2019-07-26 15:23:25.4770
# ...
